# %%
import numpy as np
import pandas as pd

# %%
from pathlib import Path

csv_path = Path('../data/processed/superstore_sales_clean.csv')
raw_csv_path = Path('../data/raw/Superstore Dataset/Sample - Superstore.csv')

if csv_path.exists():
    df = pd.read_csv(csv_path)
elif raw_csv_path.exists():
    df = pd.read_csv(raw_csv_path)
else:
    raise FileNotFoundError('No sales data file found in the expected data folders.')

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = pd.read_excel('../data/raw/Superstore Dataset/Sample - Superstore.xls')
#       2 df.head()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...
